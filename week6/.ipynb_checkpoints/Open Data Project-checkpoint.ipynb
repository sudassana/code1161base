# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
"""These things ^^ are essential in order for everything to be working fine."""
# Out:
# 'These things ^^ are essential in order for everything to be working fine.'

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 10)

# %%
saved_style_state = matplotlib.rcParams.copy()

# %%
"""Yet I have no clue what this ^^ does, moving on."""
# Out:
# 'Yet I have no clue what this ^^ does, moving on.'

# %%
if os.path.isfile("Video_Games_Sales_as_at_22_Dec_2016.csv"):
    filepath = "Video_Games_Sales_as_at_22_Dec_2016.csv"
    print "loading from file"
else:
    print "download from the internet first"
vgsales_data = pd.read_csv(filepath)
print "done"
# Out:
# loading from file
# done

# %%
"""This command does exactly what it said, to read the .csv file."""
# Out:
# 'This command does exactly what it said, to read the .csv file.'

# %%
vgsales_data.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
"""Load the header of the table. Now for loading the columns, do this."""
# Out:
# 'Load the header of the table. Now for loading the columns, do this.'

# %%
vgsales_data.columns
# Out:
# Index([u'Name', u'Platform', u'Year_of_Release', u'Genre', u'Publisher',
#        u'NA_Sales', u'EU_Sales', u'JP_Sales', u'Other_Sales', u'Global_Sales',
#        u'Critic_Score', u'Critic_Count', u'User_Score', u'User_Count',
#        u'Developer', u'Rating'],
#       dtype='object')

# %%
"""FOr example, I want to pick up the information of row seventeenth, I should type this:"""
# Out:
# 'FOr example, I want to pick up the information of row seventeenth, I should type this:'

# %%
row_seventeenth = vgsales_data.iloc[17]
row_seventeenth
# Out:
# Name               Grand Theft Auto: San Andreas
# Platform                                     PS2
# Year_of_Release                             2004
# Genre                                     Action
# Publisher                   Take-Two Interactive
# NA_Sales                                    9.43
# EU_Sales                                     0.4
# JP_Sales                                    0.41
# Other_Sales                                10.57
# Global_Sales                               20.81
# Critic_Score                                  95
# Critic_Count                                  80
# User_Score                                     9
# User_Count                                  1588
# Developer                         Rockstar North
# Rating                                         M
# Name: 17, dtype: object

# %%
vgsales_data["Name"]
# Out:
# 0                                               Wii Sports
# 1                                        Super Mario Bros.
# 2                                           Mario Kart Wii
# 3                                        Wii Sports Resort
# 4                                 Pokemon Red/Pokemon Blue
# 5                                                   Tetris
# 6                                    New Super Mario Bros.
# 7                                                 Wii Play
# 8                                New Super Mario Bros. Wii
# 9                                                Duck Hunt
# 10                                              Nintendogs
# 11                                           Mario Kart DS
# 12                             Pokemon Gold/Pokemon Silver
# 13                                                 Wii Fit
# 14                                      Kinect Adventures!
# 15                                            Wii Fit Plus
# ...

# %%
row_seventeenth["Publisher"]
# Out:
# 'Take-Two Interactive'

# %% [markdown]
# What about the score about this specific game? Put Critic Score inside the bracket.

# %%
row_seventeenth["Critic_Score"]
# Out:
# 95.0

# %%
"""Now let's try to create a historgram of every critic scores in this dataset."""
vgsales_data["Critic_Score"].hist()

# %% [markdown]
# That is a lot of data in the histogram, now I will limit the score greater than 70

# %%
vgsales_data["Critic_Score"][vgsales_data["Critic_Score"] > 70].hist()

# %% [markdown]
# But before, what if the Critic_Score was in plot diagram?

# %%
vgsales_data["Critic_Score"].plot()

# %% [markdown]
# Let's see what is the histogram looks like for GOTY worthy games (critic score > 90)

# %%
vgsales_data["Critic_Score"][vgsales_data["Critic_Score"] > 90].hist()

# %% [markdown]
# Video game consoles exist from the 80s and there is a lot of them and their games too.
# Let see how much are they in this dataset:

# %%
vgsales_data["Platform"].value_counts()
# Out:
# PS2     2161
# DS      2152
# PS3     1331
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# GC       556
# 3DS      520
# PSV      432
# PS4      393
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# GB        98
# NES       98
# DC        52
# GEN       29
# NG        12
# WS         6
# SCD        6
# 3DO        3
# TG16       2
# PCFX       1
# GG         1
# Name: Platform, dtype: int64

# %% [markdown]
# Now it's time to convert it into a diagram!

# %%
vgsales_data["Platform"].value_counts().plot(kind="bar")

plt.xlabel('Platform', fontsize = 25)
plt.ylabel('Count', fontsize = 25)

# %% [markdown]
# Now we have seen the available platforms that exist in this dataset, another thing that might be interesting
# is the total of each genres of video games.

# %%
vgsales_data["Genre"].value_counts().plot(kind= "bar")

plt.xlabel('Genre', fontsize = 25)
plt.ylabel('Count', fontsize = 25)

# %% [markdown]
# From the diagram above, it is a fact that Action video games are massively produced.

# %%
sum_row=vgsales_data[["NA_Sales","EU_Sales","JP_Sales"]].sum()
sum_row.hist()

# %%
stuff = vgsales_data[["Genre","NA_Sales","EU_Sales","JP_Sales"]].groupby("Genre").sum()

stuff.hist()
plt.xlabel("Sales", fontsize = 25)
plt.ylabel("Genre", fontsize = 25)

# %%
matplotlib.rcParams.update(saved_style_state)

# %%
stuff = vgsales_data[["Genre","NA_Sales","EU_Sales","JP_Sales"]].groupby("Genre").sum()

stuff.hist()
plt.title("Test", fontsize = 25)
plt.xlabel("Sales", fontsize = 25)
plt.ylabel("Genre", fontsize = 25)
